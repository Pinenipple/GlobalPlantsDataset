# %%
import pandas as pd

# %%
df_gp = pd.read_csv("global_power_plant_database.csv")

df_gp = df_gp.dropna(axis='columns', how='all')

print(df_gp.head())

print("Column names:\n", df_gp.columns)
# Out:
#   country country_long                                              name  \
# 0     AFG  Afghanistan      Kajaki Hydroelectric Power Plant Afghanistan
# 1     AFG  Afghanistan                                      Kandahar DOG
# 2     AFG  Afghanistan                                      Kandahar JOL
# 3     AFG  Afghanistan     Mahipar Hydroelectric Power Plant Afghanistan
# 4     AFG  Afghanistan  Naghlu Dam Hydroelectric Power Plant Afghanistan
#
#       gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0  GEODB0040538         33.0    32.322    65.1190        Hydro         NaN
# 1    WKS0070144         10.0    31.670    65.7950        Solar         NaN
# 2    WKS0071196         10.0    31.623    65.7920        Solar         NaN
# 3  GEODB0040541         66.0    34.556    69.4787        Hydro         NaN
# 4  GEODB0040534        100.0    34.641    69.7170        Hydro         NaN
#
#   other_fuel2  ... estimated_generation_gwh_2013  \
# ...

# %%
df_1 = pd.read_csv("worldbank.csv")

df_1 = df_1.dropna(axis='columns', how='all')

print(df_1.head())

print("Column names:\n", df_1.columns)
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name              Series Code  \
# 0  Carbon dioxide (CO2) emissions from Building (...  EN.GHG.CO2.BU.MT.CE.AR5
# 1                              Coal rents (% of GDP)        NY.GDP.COAL.RT.ZS
# 2      Adjusted savings: energy depletion (% of GNI)        NY.ADJ.DNGY.GN.ZS
# 3   Adjusted savings: energy depletion (current US$)           NY.ADJ.DNGY.CD
# 4  Alternative and nuclear energy (% of total ene...        EG.USE.COMM.CL.ZS
#
#   1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963] 1964 [YR1964]  \
# 0            ..            ..            ..            ..            ..
# 1            ..            ..            ..            ..            ..
# 2            ..            ..            ..            ..            ..
# ...

# %%
df_2 = pd.read_excel("World Energy Balances Highlights 2024.xlsx", 
                     sheet_name="TimeSeries_1971-2023")

df_2 = df_2.dropna(axis='columns', how='all')

print(df_2.head())

print("Column names:\n", df_2.columns)
# Out:
#   Source: IEA (2024). All rights reserved. (https://www.iea.org/terms)  \
# 0                                            Country
# 1                                          Australia
# 2                                          Australia
# 3                                          Australia
# 4                                          Australia
#
#                  Unnamed: 1                Unnamed: 2     Unnamed: 3  \
# 0                   Product                      Flow      NoCountry
# 1  Coal, peat and oil shale           Production (PJ)  01. Australia
# 2  Coal, peat and oil shale              Imports (PJ)  01. Australia
# 3  Coal, peat and oil shale              Exports (PJ)  01. Australia
# 4  Coal, peat and oil shale  Total energy supply (PJ)  01. Australia
#
#                      Unnamed: 4                    Unnamed: 5   Unnamed: 6  \
# 0                     NoProduct                        NoFlow         1971
# ...
